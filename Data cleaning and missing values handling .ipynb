# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('dirty data.csv')

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com           Missing
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN               NaN
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com               NaN
# 9         NaN       NaN            NaN                NaN               NaN
# 10    Missing       NaN            NaN                NaN                No
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.isna()
# Out:
#     first_name  last_name  full_name  email  Profession  Salary    Age  \
# 0        False      False      False  False       False   False  False
# 1        False      False      False  False       False   False  False
# 2        False      False      False  False       False   False  False
# 3        False      False      False  False       False   False  False
# 4        False      False      False  False       False    True  False
# 5         True      False       True   True        True   False  False
# 6         True      False      False   True       False   False  False
# 7        False      False      False   True       False    True   True
# 8        False      False      False  False        True   False   True
# 9         True       True       True   True        True   False  False
# 10       False       True       True   True       False   False  False
#
#     Experience  Gender   JobS  Country
# 0        False   False  False    False
# ...

# %%
df.isna().sum()
# Out:
# first_name    3
# last_name     2
# full_name     3
# email         5
# Profession    3
# Salary        2
# Age           2
# Experience    3
# Gender        4
# JobS          3
# Country       0
# dtype: int64

# %%
df.dropna()
# Out:
#   first_name last_name    full_name         email        Profession   Salary  \
# 0      Alice     Brown  Alice Brown  ab@gmail.com  Business Analyst  58000.0
# 1      Robin      Khan   Robin Khan  rk@gmail.com      Data Analyst  45000.0
# 2     Shahin      Khan  Shahin Khan  sk@yahoo.com           Missing  38000.0
#
#     Age Experience Gender JobS        Country
# 0  24.0          5      F  Yes  United States
# 1  23.0          3      M  Yes     Bangladesh
# 2  22.0          2      M   No          India

# %%
df.dropna(how='any')
# Out:
#   first_name last_name    full_name         email        Profession   Salary  \
# 0      Alice     Brown  Alice Brown  ab@gmail.com  Business Analyst  58000.0
# 1      Robin      Khan   Robin Khan  rk@gmail.com      Data Analyst  45000.0
# 2     Shahin      Khan  Shahin Khan  sk@yahoo.com           Missing  38000.0
#
#     Age Experience Gender JobS        Country
# 0  24.0          5      F  Yes  United States
# 1  23.0          3      M  Yes     Bangladesh
# 2  22.0          2      M   No          India

# %%
df.dropna(how='all')
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com           Missing
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN               NaN
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com               NaN
# 9         NaN       NaN            NaN                NaN               NaN
# 10    Missing       NaN            NaN                NaN                No
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.dropna(axis=0)
# Out:
#   first_name last_name    full_name         email        Profession   Salary  \
# 0      Alice     Brown  Alice Brown  ab@gmail.com  Business Analyst  58000.0
# 1      Robin      Khan   Robin Khan  rk@gmail.com      Data Analyst  45000.0
# 2     Shahin      Khan  Shahin Khan  sk@yahoo.com           Missing  38000.0
#
#     Age Experience Gender JobS        Country
# 0  24.0          5      F  Yes  United States
# 1  23.0          3      M  Yes     Bangladesh
# 2  22.0          2      M   No          India

# %%
df.dropna(axis=1)
# Out:
#           Country
# 0   United States
# 1      Bangladesh
# 2           India
# 3           India
# 4          Canada
# 5         Missing
# 6      Bangladesh
# 7           India
# 8          Canada
# 9   United States
# 10     Bangladesh

# %%
df.dropna('columns')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\1424125127.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df.dropna('columns')
#           Country
# 0   United States
# 1      Bangladesh
# 2           India
# 3           India
# 4          Canada
# 5         Missing
# 6      Bangladesh
# 7           India
# 8          Canada
# 9   United States
# 10     Bangladesh

# %%
df.dropna('rows')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\706993827.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   df.dropna('rows')
#   first_name last_name    full_name         email        Profession   Salary  \
# 0      Alice     Brown  Alice Brown  ab@gmail.com  Business Analyst  58000.0
# 1      Robin      Khan   Robin Khan  rk@gmail.com      Data Analyst  45000.0
# 2     Shahin      Khan  Shahin Khan  sk@yahoo.com           Missing  38000.0
#
#     Age Experience Gender JobS        Country
# 0  24.0          5      F  Yes  United States
# 1  23.0          3      M  Yes     Bangladesh
# 2  22.0          2      M   No          India

# %%
df.drop('email',axis=1)
# Out:
#    first_name last_name      full_name        Profession   Salary   Age  \
# 0       Alice     Brown    Alice Brown  Business Analyst  58000.0  24.0
# 1       Robin      Khan     Robin Khan      Data Analyst  45000.0  23.0
# 2      Shahin      Khan    Shahin Khan           Missing  38000.0  22.0
# 3      Nazmul     haque   Nazmul haque        Programmer  35000.0  24.0
# 4        Abir     Hasan     Abir Hasan    Data Scientist      NaN  28.0
# 5         NaN     Newaz            NaN               NaN  25000.0  26.0
# 6         NaN     Akter       NA Akter          Engineer  30000.0  25.0
# 7       Akash    Sarkar   Akash Sarkar         Developer      NaN   NaN
# 8      Mahbub    Rahman  Mahbub Rahman               NaN  35000.0   NaN
# 9         NaN       NaN            NaN               NaN  40000.0  19.0
# 10    Missing       NaN            NaN                No  48000.0  21.0
#
#    Experience Gender JobS        Country
# 0           5      F  Yes  United States
# ...

# %%
df.drop(3, axis=0)
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com           Missing
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN               NaN
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com               NaN
# 9         NaN       NaN            NaN                NaN               NaN
# 10    Missing       NaN            NaN                NaN                No
#
#      Salary   Age Experience Gender JobS        Country
# 0   58000.0  24.0          5      F  Yes  United States
# ...

# %%
df.dropna(subset=['email','Age'])
# Out:
#   first_name last_name     full_name           email        Profession  \
# 0      Alice     Brown   Alice Brown    ab@gmail.com  Business Analyst
# 1      Robin      Khan    Robin Khan    rk@gmail.com      Data Analyst
# 2     Shahin      Khan   Shahin Khan    sk@yahoo.com           Missing
# 3     Nazmul     haque  Nazmul haque  nh@hotmail.com        Programmer
# 4       Abir     Hasan    Abir Hasan    ah@email.com    Data Scientist
#
#     Salary   Age Experience Gender JobS        Country
# 0  58000.0  24.0          5      F  Yes  United States
# 1  45000.0  23.0          3      M  Yes     Bangladesh
# 2  38000.0  22.0          2      M   No          India
# 3  35000.0  24.0        NaN      M   No          India
# 4      NaN  28.0          5      M  Yes         Canada

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com           Missing
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN               NaN
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com               NaN
# 9         NaN       NaN            NaN                NaN               NaN
# 10    Missing       NaN            NaN                NaN                No
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.fillna(0)
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com           Missing
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5           0     Newaz              0                  0                 0
# 6           0     Akter       NA Akter                  0          Engineer
# 7       Akash    Sarkar   Akash Sarkar                  0         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com                 0
# 9           0         0              0                  0                 0
# 10    Missing         0              0                  0                No
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.dtypes
# Out:
# first_name     object
# last_name      object
# full_name      object
# email          object
# Profession     object
# Salary        float64
# Age           float64
# Experience     object
# Gender         object
# JobS           object
# Country        object
# dtype: object

# %%
df[['Age', 'Salary']]
# Out:
#      Age   Salary
# 0   24.0  58000.0
# 1   23.0  45000.0
# 2   22.0  38000.0
# 3   24.0  35000.0
# 4   28.0      NaN
# 5   26.0  25000.0
# 6   25.0  30000.0
# 7    NaN      NaN
# 8    NaN  35000.0
# 9   19.0  40000.0
# 10  21.0  48000.0

# %%
sub_df=df[['Age','Salary']]

# %%
sub_df
# Out:
#      Age   Salary
# 0   24.0  58000.0
# 1   23.0  45000.0
# 2   22.0  38000.0
# 3   24.0  35000.0
# 4   28.0      NaN
# 5   26.0  25000.0
# 6   25.0  30000.0
# 7    NaN      NaN
# 8    NaN  35000.0
# 9   19.0  40000.0
# 10  21.0  48000.0

# %%
sub_df.describe()
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   23.555556  39333.333333
# std     2.697736   9924.716621
# min    19.000000  25000.000000
# 25%    22.000000  35000.000000
# 50%    24.000000  38000.000000
# 75%    25.000000  45000.000000
# max    28.000000  58000.000000

# %%
df['Age'].mean()
# Out:
# 23.555555555555557

# %%
df['Age'].median()
# Out:
# 24.0

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
sub_df['Age'].fillna(sub_df['Age'].mean())
# Out:
# 0     24.000000
# 1     23.000000
# 2     22.000000
# 3     24.000000
# 4     28.000000
# 5     26.000000
# 6     25.000000
# 7     23.555556
# 8     23.555556
# 9     19.000000
# 10    21.000000
# Name: Age, dtype: float64

# %%
sub_df['Age'].fillna(round(sub_df['Age'].mean()), inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\1782779256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Age'].fillna(round(sub_df['Age'].mean()), inplace=True)

# %%
sub_df['Age'].fillna(sub_df['Age'].mean(), inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\2515863164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Age'].fillna(sub_df['Age'].mean(), inplace=True)

# %%
sub_df['Age']
# Out:
# 0     24.0
# 1     23.0
# 2     22.0
# 3     24.0
# 4     28.0
# 5     26.0
# 6     25.0
# 7     24.0
# 8     24.0
# 9     19.0
# 10    21.0
# Name: Age, dtype: float64

# %%
sub_df['Salary'].fillna(sub_df['Salary'].mean())
# Out:
# 0     58000.000000
# 1     45000.000000
# 2     38000.000000
# 3     35000.000000
# 4     39333.333333
# 5     25000.000000
# 6     30000.000000
# 7     39333.333333
# 8     35000.000000
# 9     40000.000000
# 10    48000.000000
# Name: Salary, dtype: float64

# %%
sub_df['Salary'].fillna(round(sub_df['Salary'].mean()), inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\1488643428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Salary'].fillna(round(sub_df['Salary'].mean()), inplace=True)

# %%
sub_df['Salary']
# Out:
# 0     58000.0
# 1     45000.0
# 2     38000.0
# 3     35000.0
# 4     39333.0
# 5     25000.0
# 6     30000.0
# 7     39333.0
# 8     35000.0
# 9     40000.0
# 10    48000.0
# Name: Salary, dtype: float64

# %%
sub_df
# Out:
#      Age   Salary
# 0   24.0  58000.0
# 1   23.0  45000.0
# 2   22.0  38000.0
# 3   24.0  35000.0
# 4   28.0  39333.0
# 5   26.0  25000.0
# 6   25.0  30000.0
# 7   24.0  39333.0
# 8   24.0  35000.0
# 9   19.0  40000.0
# 10  21.0  48000.0

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['first_name'].value_counts()
# Out:
# Alice     1
# Robin     1
# Shahin    1
# Nazmul    1
# Abir      1
# Akash     1
# Mahbub    1
# Rezwan    1
# Name: first_name, dtype: int64

# %%
df['first_name'].replace('Missing', 'Rezwan')
# Out:
# 0      Alice
# 1      Robin
# 2     Shahin
# 3     Nazmul
# 4       Abir
# 5        NaN
# 6        NaN
# 7      Akash
# 8     Mahbub
# 9        NaN
# 10    Rezwan
# Name: first_name, dtype: object

# %%
df['first_name'].replace('Missing', 'Rezwan', inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Profession'].replace('Missing', 'Programmer')
# Out:
# 0     Business Analyst
# 1         Data Analyst
# 2           Programmer
# 3           Programmer
# 4       Data Scientist
# 5           programmer
# 6             Engineer
# 7            Developer
# 8           programmer
# 9           programmer
# 10        Data Analyst
# Name: Profession, dtype: object

# %%
df['Profession'].replace('Missing', 'Programmer', inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Experience'].replace('Missing', 0, inplace=True)

# %%
df['Experience'].fillna(0)
# Out:
# 0     5
# 1     3
# 2     2
# 3     0
# 4     5
# 5     0
# 6     0
# 7     0
# 8     8
# 9     7
# 10    5
# Name: Experience, dtype: object

# %%
df['Experience'].fillna(0, inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.dtypes
# Out:
# first_name     object
# last_name      object
# full_name      object
# email          object
# Profession     object
# Salary         object
# Age           float64
# Experience     object
# Gender         object
# JobS           object
# Country        object
# dtype: object

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df["Gender"].fillna('M',inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df["JobS"].fillna('No',inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Experience'].fillna(0, inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df["Profession"].fillna('Data Analyst')
# Out:
# 0     Business Analyst
# 1         Data Analyst
# 2           Programmer
# 3           Programmer
# 4       Data Scientist
# 5           programmer
# 6             Engineer
# 7            Developer
# 8           programmer
# 9           programmer
# 10        Data Analyst
# Name: Profession, dtype: object

# %%
df['Profession'].replace('No','Data Analyst', inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Profession'].fillna('Programmer')
# Out:
# 0     Business Analyst
# 1         Data Analyst
# 2           Programmer
# 3           Programmer
# 4       Data Scientist
# 5           programmer
# 6             Engineer
# 7            Developer
# 8           programmer
# 9           programmer
# 10        Data Analyst
# Name: Profession, dtype: object

# %%
df['Profession'].fillna('programmer', inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
sub_df['Salary'].fillna(round(sub_df['Salary'].mean()),inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\927447399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_df['Salary'].fillna(round(sub_df['Salary'].mean()),inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5         NaN     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Salary'].fillna('30000.0')
# Out:
# 0     58000.0
# 1     45000.0
# 2     38000.0
# 3     35000.0
# 4     30000.0
# 5     25000.0
# 6     30000.0
# 7     30000.0
# 8     35000.0
# 9     40000.0
# 10    48000.0
# Name: Salary, dtype: object

# %%
df['Salary'].fillna('30000.0', inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Age'].fillna(24)
# Out:
# 0     24.0
# 1     23.0
# 2     22.0
# 3     24.0
# 4     28.0
# 5     26.0
# 6     25.0
# 7     24.0
# 8     24.0
# 9     19.0
# 10    21.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(24, inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['Salary'].replace('Arafin',35000.0, inplace=True)

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6         NaN     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.iloc[6,0]='Rafe'

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6        Rafe     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9         NaN       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.iloc[9,0]='Al Amin'

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6        Rafe     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin       NaN            NaN                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.iloc[9,1]='Hossain'

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6        Rafe     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain        Hossain                NaN        programmer
# 10     Rezwan       NaN            NaN                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df.iloc[10,1]='Ahmed'

# %%
df
# Out:
#    first_name last_name      full_name              email        Profession  \
# 0       Alice     Brown    Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan     Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan    Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque   Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan     Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz            NaN                NaN        programmer
# 6        Rafe     Akter       NA Akter                NaN          Engineer
# 7       Akash    Sarkar   Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman  Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain        Hossain                NaN        programmer
# 10     Rezwan     Ahmed          Ahmed                NaN      Data Analyst
#
#      Salary   Age Experience Gender JobS        Country
# ...

# %%
df['full_name'].replace('Hossain', 'Al Amin Hossain', inplace=True)

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz              NaN                NaN        programmer
# 6        Rafe     Akter         NA Akter                NaN          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed            Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[5,2]='Arafin Newaz'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz                NaN        programmer
# 6        Rafe     Akter         NA Akter                NaN          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed            Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[5,2]='Arafin Newaz'(inplace=True)
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\3904342405.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df.iloc[5,2]='Arafin Newaz'(inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\3904342405.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df.iloc[5,2]='Arafin Newaz'(inplace=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_10300\3904342405.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df.iloc[5,2]='Arafin Newaz'(inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [158], in <cell line: 1>()
# ----> 1 df.iloc[5,2]='Arafin Newaz'(inplace=True)
#
# ...

# %%
df.iloc[6,2]='Rafe Akter'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz                NaN        programmer
# 6        Rafe     Akter       Rafe Akter                NaN          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed            Ahmed                NaN      Data Analyst
#
# ...

# %%
df['full_name'].replace('Ahmed', 'Rezwan Ahmed',inplace=True)

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz                NaN        programmer
# 6        Rafe     Akter       Rafe Akter                NaN          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[5,3]='ah@gmail.com'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter                NaN          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[6,3]='ra@hotmail.com'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar                NaN         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[7,3]='as@hotmail.com'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain                NaN        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[9,3]='ah@hotmail.com'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed                NaN      Data Analyst
#
# ...

# %%
df.iloc[10,3]='ra@gmail.com'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...

# %%
df.iloc[8,8]='M'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...

# %%
df.iloc[10,8]='M'

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe     Akter       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...

# %%
df['last_name'].replace('Akter','Talukder',inplace=True)

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe  Talukder       Rafe Akter     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...

# %%
df['full_name'].replace('Rafe Akter','Rafe Talukder',inplace=True)

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe  Talukder    Rafe Talukder     ra@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...

# %%
df['email'].replace('ra@hotmail.com','rt@hotmail.com',inplace=True)

# %%
df
# Out:
#    first_name last_name        full_name              email        Profession  \
# 0       Alice     Brown      Alice Brown       ab@gmail.com  Business Analyst
# 1       Robin      Khan       Robin Khan       rk@gmail.com      Data Analyst
# 2      Shahin      Khan      Shahin Khan       sk@yahoo.com        Programmer
# 3      Nazmul     haque     Nazmul haque     nh@hotmail.com        Programmer
# 4        Abir     Hasan       Abir Hasan       ah@email.com    Data Scientist
# 5      Arafin     Newaz     Arafin Newaz       ah@gmail.com        programmer
# 6        Rafe  Talukder    Rafe Talukder     rt@hotmail.com          Engineer
# 7       Akash    Sarkar     Akash Sarkar     as@hotmail.com         Developer
# 8      Mahbub    Rahman    Mahbub Rahman  mrahman@gmail.com        programmer
# 9     Al Amin   Hossain  Al Amin Hossain     ah@hotmail.com        programmer
# 10     Rezwan     Ahmed     Rezwan Ahmed       ra@gmail.com      Data Analyst
#
# ...
